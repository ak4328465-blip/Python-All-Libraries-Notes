# %% [markdown]
# ############################# PANDAS #########################

# %% [markdown]
# why pandas?
#
# 1. Import datasets
# 2. Data cleansing
# 3. Size mutability
# 4. Reshaping and pivoting of datasets
# 5. Efficient manipulation and extraction
# 6. Statistical analysis

# %% [markdown]
# 2 Primary Data Structure
#
# 1. Series
# 2. DataFrame

# %% [markdown]
# Data structure are collection of data types that provide the best way of organizing the (values) in terms of memory usage

# %% [markdown]
# 1. Series --> A one dimensional labeled homogeneous array, size immutable.

# %% [markdown]
# 2. DataFrame--> A two-dimensional labeled, Size-mutable tabular structure with potentially heterogeneously typed
# columns

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name="Numbers"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
#Indexing 
s[0]
# Out:
# np.int64(10)

# %%
s[0:2] #Start(included): stop (excluded): step value (values to jump)
# Out:
# 0    10
# 1    20
# Name: Numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: Numbers, dtype: int64

# %%
# iloc ->location bassed indexing

s.iloc[3]
# Out:
# np.int64(40)

# %%
s.iloc[[1,3,4]]
# Out:
# 1    20
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
s.name="calories"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: calories, dtype: int64

# %%
index=['apple','banana','grapes','orange','strawberry']
s.index=index
s
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: calories, dtype: int64

# %%
s['grapes']
# Out:
# np.int64(30)

# %%
s.iloc[3] #-->iloc works only if you know the indexes
# Out:
# np.int64(40)

# %%
# loc --> label based indexing
s.loc['grapes']
# Out:
# np.int64(30)

# %%
# In label based indexing your start as well as stop values both are included in the output. 
s.loc['banana':'orange']
# Out:
# banana    20
# grapes    30
# orange    40
# Name: calories, dtype: int64

# %%
s.loc[['orange','apple']]
# Out:
# orange    40
# apple     10
# Name: calories, dtype: int64

# %%
fruit_protein={
    "Avocado":2.0,     # grams of protein
    'Guava':2.6,
    "Blackberries":2.0,
    "oranges":0.9,
    "Banana":1.1,
    "Apples":0.3,
    "Kiwi":1.1,
    "promegranate":1.7,
    "mango":0.8,
    "Cherries":1.0
    
}

fruit_protein
# Out:
# {'Avocado': 2.0,
#  'Guava': 2.6,
#  'Blackberries': 2.0,
#  'oranges': 0.9,
#  'Banana': 1.1,
#  'Apples': 0.3,
#  'Kiwi': 1.1,
#  'promegranate': 1.7,
#  'mango': 0.8,
#  'Cherries': 1.0}

# %%
s2=pd.Series(fruit_protein,name="Protein")
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
s2.iloc[3]
# Out:
# np.float64(0.9)

# %%
s2.loc[['Banana','mango']]
# Out:
# Banana    1.1
# mango     0.8
# Name: Protein, dtype: float64

# %%
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
# Coditional Selection

s2>1
# Out:
# Avocado          True
# Guava            True
# Blackberries     True
# oranges         False
# Banana           True
# Apples          False
# Kiwi             True
# promegranate     True
# mango           False
# Cherries        False
# Name: Protein, dtype: bool

# %%
s2[s2>1]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Banana          1.1
# Kiwi            1.1
# promegranate    1.7
# Name: Protein, dtype: float64

# %%
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
# Logical Operators:-->(and, or , not)
[(s2>0.5) & (s2<2)]
# Out:
# [Avocado         False
#  Guava           False
#  Blackberries    False
#  oranges          True
#  Banana           True
#  Apples          False
#  Kiwi             True
#  promegranate     True
#  mango            True
#  Cherries         True
#  Name: Protein, dtype: bool]

# %%
 # or operators
s2[(s2>0.5) | (s2<=2)]
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
# not operation:
[~(s2>1)]
# Out:
# [Avocado         False
#  Guava           False
#  Blackberries    False
#  oranges          True
#  Banana          False
#  Apples           True
#  Kiwi            False
#  promegranate    False
#  mango            True
#  Cherries         True
#  Name: Protein, dtype: bool]

# %%
s2[~(s2>1)]
# Out:
# oranges     0.9
# Apples      0.3
# mango       0.8
# Cherries    1.0
# Name: Protein, dtype: float64

# %%
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
# Modyfying the series

s2["mango"]=2.8
s2
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# promegranate    1.7
# mango           2.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %%
import numpy as np
ser=pd.Series(["a",np.nan,1,np.nan,2])
print('Not null values',ser.notnull().sum())
print('is null values',ser.isnull().sum())
# Out:
# Not null values 3
# is null values 2

# %% [markdown]
# DataFrame

# %%
#DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.head(2)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
df.tail(2)
# Out:
#     Name   Age Department   Salary
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  50000.0

# %%
# loc and iloc

df.iloc[1:3]
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0

# %%
df.loc[:,'Department']
# Out:
# 0         HR
# 1         IT
# 2    Finance
# 3         IT
# 4         HR
# 5         HR
# Name: Department, dtype: object

# %%
df.loc[1:3,['Age',"Department"]]
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT

# %%
df[['Age','Department']]
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %%
df.drop('Age',axis=1)# axis =1 is means columns index and axis=0 means Row index
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.drop('Age',axis=1,inplace=True) # changes with the original datafram

# %%
df
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
df.shape
# Out:
# (6, 3)

# %%
# i have inserted 2nd  times data
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      object
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      object
#  3   Salary      5 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %%
df['Salary'].values
# Out:
# array([50000., 60000., 70000., 62000.,    nan, 50000.])

# %%
# Broadcasting 

df['Salary']=df['Salary'] + 5000

# %%
df['Salary']
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4        NaN
# 5    55000.0
# Name: Salary, dtype: float64

# %%
# Renaming Columns:

df.rename(columns={"Department":"Dept"},inplace= True)

# %%
df
# Out:
#       Name   Age     Dept   Salary
# 0    Alice  25.0       HR  55000.0
# 1      Bob  30.0       IT  65000.0
# 2  Charlie  35.0  Finance  75000.0
# 3    David   NaN       IT  67000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  55000.0

# %%
df['Salary'].unique()
# Out:
# array([55000., 65000., 75000., 67000.,    nan])

# %%
df['Dept'].unique()
# Out:
# array(['HR', 'IT', 'Finance'], dtype=object)

# %%
df['Dept'].value_counts()
# Out:
# Dept
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
# Broadcasting

df['Promoted Salary']=df["Salary"] * 10

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3    David   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
# Data Cleaning 

df.isnull().sum()
# Out:
# Name               0
# Age                1
# Dept               0
# Salary             1
# Promoted Salary    1
# dtype: int64

# %%
df.dropna(how='any') # any row that had any null values
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df.dropna(how='all') # if all the values in any row ara null the we drop.
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3    David   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %% [markdown]
# Handel with missing values
#
# 1. getting rid --> dropna()
# 2. filling them up --> fillna()

# %%
df.fillna(0)
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3    David   0.0       IT  67000.0         670000.0
# 4      Eve  29.0       HR      0.0              0.0
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df["Age"].fillna(df["Age"].mean()) #you can use inplace is Ture
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Salary'].fillna(df['Salary'].mean())
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4    63400.0
# 5    55000.0
# Name: Salary, dtype: float64

# %% [markdown]
# In fillna have 2 methods
#
# 1. Forward fill
# 2. Backward fill

# %%
df['Age'].fillna(method='ffill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3868\1265906299.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='ffill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(method='bfill')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3868\3224957626.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='bfill')
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
df
# Out:
#       Name   Age     Dept   Salary  Promoted Salary
# 0    Alice  25.0       HR  55000.0         550000.0
# 1      Bob  30.0       IT  65000.0         650000.0
# 2  Charlie  35.0  Finance  75000.0         750000.0
# 3    David   NaN       IT  67000.0         670000.0
# 4      Eve  29.0       HR      NaN              NaN
# 5    Alice  25.0       HR  55000.0         550000.0

# %%
df['Name']=df['Name'].replace("Charlie","Rose")
df
# Out:
#     Name   Age     Dept   Salary  Promoted Salary
# 0  Alice  25.0       HR  55000.0         550000.0
# 1    Bob  30.0       IT  65000.0         650000.0
# 2   Rose  35.0  Finance  75000.0         750000.0
# 3  David   NaN       IT  67000.0         670000.0
# 4    Eve  29.0       HR      NaN              NaN
# 5  Alice  25.0       HR  55000.0         550000.0

# %%
# Duplicates:

df_dup= df[df.duplicated(keep="first")]
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted Salary
# 5  Alice  25.0   HR  55000.0         550000.0

# %%
df_dup=df[df.duplicated(keep="last")]
df_dup
# Out:
#     Name   Age Dept   Salary  Promoted Salary
# 0  Alice  25.0   HR  55000.0         550000.0

# %%
# remove duplicate values

df=df.drop_duplicates()
df
# Out:
#     Name   Age     Dept   Salary  Promoted Salary
# 0  Alice  25.0       HR  55000.0         550000.0
# 1    Bob  30.0       IT  65000.0         650000.0
# 2   Rose  35.0  Finance  75000.0         750000.0
# 3  David   NaN       IT  67000.0         670000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
## invalid Values:
# lambda --> python

df['Promoted Salary']=df["Promoted Salary"].apply(lambda x: x/10 if x >650000 else x)
df
# Out:
#     Name   Age     Dept   Salary  Promoted Salary
# 0  Alice  25.0       HR  55000.0         550000.0
# 1    Bob  30.0       IT  65000.0         650000.0
# 2   Rose  35.0  Finance  75000.0          75000.0
# 3  David   NaN       IT  67000.0          67000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
name='alice_fernandes'
df[['first_name', 'last_name']] = df['name'].str.split("_")

# %%
# apply and lambda 
def multiplying_age(x):
    return x*2

df['Age'] = df['Age'].apply(multiplying_age)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted Salary
# 0  Alice  50.0       HR  55000.0         550000.0
# 1    Bob  60.0       IT  65000.0         650000.0
# 2   Rose  70.0  Finance  75000.0          75000.0
# 3  David   NaN       IT  67000.0          67000.0
# 4    Eve  58.0       HR      NaN              NaN

# %%
df['Age']=df['Age'].apply(lambda x: x/2)

# %%
df
# Out:
#     Name   Age     Dept   Salary  Promoted Salary
# 0  Alice  25.0       HR  55000.0         550000.0
# 1    Bob  30.0       IT  65000.0         650000.0
# 2   Rose  35.0  Finance  75000.0          75000.0
# 3  David   NaN       IT  67000.0          67000.0
# 4    Eve  29.0       HR      NaN              NaN

# %%
# Joins and Merges


department_info = {
    "Dept": ["HR", "IT", "Finance"],
    "Location": ["New York", "San Francisco", "Chicago"],
    "Manager": ["Laura", "Steve", "Nina"]
}

df2 = pd.DataFrame(department_info)

# %%
df2
# Out:
#       Dept       Location Manager
# 0       HR       New York   Laura
# 1       IT  San Francisco   Steve
# 2  Finance        Chicago    Nina

# %%
# Concat

pd.concat([df,df2])
# Out:
#     Name   Age     Dept   Salary  Promoted Salary       Location Manager
# 0  Alice  25.0       HR  55000.0         550000.0            NaN     NaN
# 1    Bob  30.0       IT  65000.0         650000.0            NaN     NaN
# 2   Rose  35.0  Finance  75000.0          75000.0            NaN     NaN
# 3  David   NaN       IT  67000.0          67000.0            NaN     NaN
# 4    Eve  29.0       HR      NaN              NaN            NaN     NaN
# 0    NaN   NaN       HR      NaN              NaN       New York   Laura
# 1    NaN   NaN       IT      NaN              NaN  San Francisco   Steve
# 2    NaN   NaN  Finance      NaN              NaN        Chicago    Nina

# %%
pd.concat([df,df2],axis=1)
# Out:
#     Name   Age     Dept   Salary  Promoted Salary     Dept       Location  \
# 0  Alice  25.0       HR  55000.0         550000.0       HR       New York
# 1    Bob  30.0       IT  65000.0         650000.0       IT  San Francisco
# 2   Rose  35.0  Finance  75000.0          75000.0  Finance        Chicago
# 3  David   NaN       IT  67000.0          67000.0      NaN            NaN
# 4    Eve  29.0       HR      NaN              NaN      NaN            NaN
#
#   Manager
# 0   Laura
# 1   Steve
# 2    Nina
# 3     NaN
# 4     NaN

# %%
pd.merge(df, df2, on ="Dept")
# Out:
#     Name   Age     Dept   Salary  Promoted Salary       Location Manager
# 0  Alice  25.0       HR  55000.0         550000.0       New York   Laura
# 1    Bob  30.0       IT  65000.0         650000.0  San Francisco   Steve
# 2   Rose  35.0  Finance  75000.0          75000.0        Chicago    Nina
# 3  David   NaN       IT  67000.0          67000.0  San Francisco   Steve
# 4    Eve  29.0       HR      NaN              NaN       New York   Laura

# %%
# if data time format dtype is object

# use this to convert into datetim[na]

# data['date']=pd.to_datetime(data['date'])
# data.info()
